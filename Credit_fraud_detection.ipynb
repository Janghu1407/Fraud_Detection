# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df = data.sample(frac = 0.2, random_state=1)
data[['Time', 'Amount', 'Class']].describe()
# Out:
#                 Time         Amount          Class
# count  284807.000000  284807.000000  284807.000000
# mean    94813.859575      88.349619       0.001727
# std     47488.145955     250.120109       0.041527
# min         0.000000       0.000000       0.000000
# 25%     54201.500000       5.600000       0.000000
# 50%     84692.000000      22.000000       0.000000
# 75%    139320.500000      77.165000       0.000000
# max    172792.000000   25691.160000       1.000000

# %%
df[['Time', 'Amount', 'Class']].describe()
# Out:
#                Time        Amount         Class
# count   56961.00000  56961.000000  56961.000000
# mean    94571.23811     88.750996      0.001527
# std     47566.88462    254.652038      0.039052
# min         0.00000      0.000000      0.000000
# 25%     53809.00000      5.950000      0.000000
# 50%     84511.00000     22.160000      0.000000
# 75%    139237.00000     77.900000      0.000000
# max    172784.00000  19656.530000      1.000000

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    56874
# 1       87
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.countplot(data['Class'])
plt.xlabel('Isfraud')
plt.ylabel('Count')
plt.show()

# %%
timedelta = pd.to_timedelta(data['Time'], unit='s')

# %%
data['Time_hour'] = (timedelta.dt.components.hours).astype(int)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
plt.figure(figsize=(12,5))
sns.distplot(data[data['Class']==0]['Time_hour'], color='g')
sns.distplot(data[data['Class']==1]['Time_hour'], color='r')
plt.xlim([-1, 25])
plt.show()

# %%
df_fraud = data[data['Class']==1]
df_normal = data[data['Class']==0]

# %%
df_fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df_normal['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(12, 5))
dfs = [data['Amount'], df_fraud['Amount'], df_normal['Amount']]
i = 0
for df in dfs:
    plt.subplot(1, 3, i+1)
    sns.distplot(np.log(df+0.01)) # for better visulatization
    i = i+1
plt.show()

# %%
cols = data.iloc[:, 1:29].columns
j = 0
plt.figure(figsize = (15, 80))
for c in cols:
    plt.subplot(14, 2, j+1)
    sns.distplot(df_fraud[c], bins=50, color = 'r')
    sns.distplot(df_normal[c], bins=50, color = 'g')
    j = j+1
    
plt.show()

# %%
cols = ['V6','V13', 'V15','V20','V22','V23','V24','V25','V26','V28', 'Time']
data.drop(cols, axis=1, inplace=True)

# %%
correlation = data.corr()

# %%
plt.figure(figsize = (20,20))
sns.heatmap(correlation, cbar=False, annot=True, square=True)
plt.show()

# %%
data['Amount'] = np.log(data['Amount']+0.01)

# %%
df = data.sample(frac = 0.2, random_state=1)

# %%
df.shape
# Out:
# (56961, 21)

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12',
#        'V14', 'V16', 'V17', 'V18', 'V19', 'V21', 'V27', 'Amount', 'Class',
#        'Time_hour'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split,GridSearchCV, RandomizedSearchCV, KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
import scipy
from sklearn.metrics import plot_precision_recall_curve

# %%
def print_results(true, pred):
    print('accuracy_score: {}'.format(accuracy_score(true, pred)))
    print('precision_score: {}'.format(precision_score(true, pred)))
    print('recall_score: {}'.format(recall_score(true, pred)))
    print('f1_score: {}'.format(f1_score(true, pred)))

# %%
#x = df.drop('Class', axis=1)
#y = df['Class']

# %%
#x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 7, test_size=0.2)

# %%
#log = LogisticRegression()
#param_grid = {'C': [0.8, 0.1, 1,  5, 10]}
#grid = GridSearchCV(log, param_grid, scoring='recall', cv=5)
#grid.fit(x_train, y_train)

# %%
#grid.best_params_

# %%
#log = LogisticRegression(C=0.8)
#log.fit(x_train, y_train)

# %%
#log_pred = log.predict(x_test)

# %%
#confusion_matrix(y_test, log_pred)

# %%
#print_results(y_test, log_pred)

# %%
#plot_precision_recall_curve(log, x_test, y_test)

# %%
#svc = SVC()
#param_grid = {'C':[0.1, 1,10,100], 'gamma': [1,0.1], 'kernel': ['rbf']}

# %%
#grid = GridSearchCV(svc, param_grid, cv=5, scoring='recall')
#grid.fit(x_train, y_train)

# %%
#grid.best_params_

# %%
#svc = SVC(C=10, gamma=0.1, kernel='rbf')

# %%
#svc.fit(x_train,y_train)

# %%
#svc_predict = svc.predict(x_test)

# %%
#confusion_matrix(y_test, svc_pred)

# %%
#print_results(y_test, svc_pred)

# %%
#plot_precision_recall_curve(svc, x_test, y_test)

# %%
#svc = SVC()

# %%
#svc.fit(x_train,y_train)

# %%
#svc_predict = svc.predict(x_test)

# %%
#confusion_matrix(y_test, svc_pred)

# %%
#print_results(y_test, svc_pred)

# %%
#plot_precision_recall_curve(svc, x_test, y_test)

# %%
#param_grid = {"max_depth": [3,5, None],
              #"n_estimators":[5,10,20],
              #"max_features": [7,8,10,15]}

# %%
#model = RandomForestClassifier(max_features=3, max_depth=2 ,n_estimators=10, random_state=3,verbose = 1)

# %%
#grid_search = GridSearchCV(model, param_grid, cv=5, scoring='recall')

# %%
#grid_search.fit(x_train, y_train)

# %%
#grid_search.best_params_

# %%
#rf = RandomForestClassifier(max_depth= None, max_features=8, n_estimators=20)

# %%
#rf.fit(x_train, y_train)

# %%
#rf_pred = rf.predict(x_test)

# %%
#confusion_matrix(y_test, rf_pred)

# %%
#print_results(y_test, rf_pred)

# %%
#plot_precision_recall_curve(rf, x_test, y_test)

# %%
#rf1 = RandomForestClassifier(random_state=0)

# %%
#rf1.fit(x_train, y_train)

# %%
#rf1_pred = rf1.predict(x_test)

# %%
#confusion_matrix(y_test, rf1_pred)

# %%
#print_results(y_test, rf1_pred)

# %%
#plot_precision_recall_curve(rf1, x_test, y_test)

# %%
#gbc = GradientBoostingClassifier(random_state=0)

# %%
#gbc.fit(x_train, y_train)

# %%
#gbc_pred = gbc.predict(x_test)

# %%
#confusion_matrix(y_test, gbc_pred)

# %%
#print_results(y_test, gbc_pred)

# %%
#param_grid = [{'max_features': [5,7,8], 
               #'n_estimators':[3, 5,10], 'learning_rate': [0.01, 0.1,1]}]

# %%
#grid_search = GridSearchCV(gbc, param_grid, cv=5, scoring='recall')

# %%
#grid_search.fit(x_train, y_train)

# %%
#grid_search.best_params_

# %%
#gbc1 = GradientBoostingClassifier(random_state=0, learning_rate= 0.1,max_features= 5,n_estimators= 10)

# %%
#gbc1.fit(x_train, y_train)

# %%
#gbc1_pred = gbc1.predict(x_test)

# %%
#confusion_matrix(y_test, gbc1_pred)

# %%
#print_results(y_test, gbc1_pred)

# %%
x = data.drop('Class', axis=1)
y = data['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 7, test_size=0.2)

# %%
log = LogisticRegression(C=0.8)

# %%
log.fit(x_train, y_train)
# Out:
# C:\Users\91885\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=0.8)

# %%
log_pred = log.predict(x_test)

# %%
confusion_matrix(y_test, log_pred)
# Out:
# array([[56853,     9],
#        [   43,    57]], dtype=int64)

# %%
print_results(y_test, log_pred)
# Out:
# accuracy_score: 0.9990871107053826
# precision_score: 0.8636363636363636
# recall_score: 0.57
# f1_score: 0.6867469879518072

# %%
plot_precision_recall_curve(log, x_test, y_test)

# %%
svc = SVC(C=10, gamma=0.1, kernel='rbf')

# %%
svc.fit(x_train,y_train)
# Out:
# SVC(C=10, gamma=0.1)

# %%
svc_pred = svc.predict(x_test)

# %%
confusion_matrix(y_test, svc_pred)
# Out:
# array([[56859,     3],
#        [   63,    37]], dtype=int64)

# %%
print_results(y_test, svc_pred)
# Out:
# accuracy_score: 0.9988413328183702
# precision_score: 0.925
# recall_score: 0.37
# f1_score: 0.5285714285714286

# %%
svc1 = SVC()

# %%
svc1.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc1_pred = svc1.predict(x_test)

# %%
confusion_matrix(y_test, svc1_pred)
# Out:
# array([[56853,     9],
#        [   15,    85]], dtype=int64)

# %%
print_results(y_test, svc1_pred)
# Out:
# accuracy_score: 0.9995786664794073
# precision_score: 0.9042553191489362
# recall_score: 0.85
# f1_score: 0.8762886597938143

# %%
plot_precision_recall_curve(svc1, x_test, y_test)

# %%
rf = RandomForestClassifier(max_depth= None, max_features=8, n_estimators=20)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_features=8, n_estimators=20)

# %%
rf_pred = rf.predict(x_test)

# %%
confusion_matrix(y_test, rf_pred)
# Out:
# array([[56856,     6],
#        [   19,    81]], dtype=int64)

# %%
print_results(y_test, rf_pred)
# Out:
# accuracy_score: 0.9995611109160493
# precision_score: 0.9310344827586207
# recall_score: 0.81
# f1_score: 0.8663101604278076

# %%
plot_precision_recall_curve(rf, x_test, y_test)

# %%
gbc1 = GradientBoostingClassifier(random_state=0, learning_rate= 0.1,max_features= 5,n_estimators= 10)

# %%
gbc1.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(max_features=5, n_estimators=10, random_state=0)

# %%
gbc1_pred = gbc1.predict(x_test)

# %%
confusion_matrix(y_test, gbc1_pred)
# Out:
# array([[56841,    21],
#        [   29,    71]], dtype=int64)

# %%
print_results(y_test, gbc1_pred)
# Out:
# accuracy_score: 0.9991222218320986
# precision_score: 0.7717391304347826
# recall_score: 0.71
# f1_score: 0.7395833333333333

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc_pred = gbc.predict(x_test)

# %%
confusion_matrix(y_test, gbc_pred)
# Out:
# array([[56845,    17],
#        [   29,    71]], dtype=int64)

# %%
print_results(y_test, gbc_pred)
# Out:
# accuracy_score: 0.9991924440855307
# precision_score: 0.8068181818181818
# recall_score: 0.71
# f1_score: 0.7553191489361702

# %%
plot_precision_recall_curve(gbc, x_test, y_test)

# %%
from sklearn.ensemble import VotingClassifier

# %%
estimators = [('RandomForest', rf),('SVC',svc1)]

# %%
vc = VotingClassifier(estimators=estimators, voting='hard')

# %%
vc.fit(x_train, y_train)
# Out:
# VotingClassifier(estimators=[('RandomForest',
#                               RandomForestClassifier(max_features=8,
#                                                      n_estimators=20)),
#                              ('SVC', SVC())])

# %%
vc_pred = vc.predict(x_test)

# %%
confusion_matrix(y_test, vc_pred)
# Out:
# array([[56859,     3],
#        [   19,    81]], dtype=int64)

# %%
print_results(y_test, vc_pred)
# Out:
# accuracy_score: 0.9996137776061234
# precision_score: 0.9642857142857143
# recall_score: 0.81
# f1_score: 0.8804347826086957

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=0)

# %%
x_train_res, y_train_res = sm.fit_sample(x_train, y_train)

# %%
y_train_res.value_counts()
# Out:
# 1    227453
# 0    227453
# Name: Class, dtype: int64

# %%
log = LogisticRegression()
param_grid = {'C': [0.8, 0.1, 1,  5, 10]}
grid = GridSearchCV(log, param_grid, cv=5)
grid.fit(x_train_res, y_train_res)
# Out:
# C:\Users\91885\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\91885\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
grid.best_params_
# Out:
# {'C': 5}

# %%
log = LogisticRegression(C=5)
log.fit(x_train_res, y_train_res)
# Out:
# LogisticRegression(C=5)

# %%
log_pred = log.predict(x_test)

# %%
confusion_matrix(y_test, log_pred)
# Out:
# array([[55292,  1570],
#        [    9,    91]], dtype=int64)

# %%
print_results(y_test, log_pred)
# Out:
# accuracy_score: 0.9722797654576736
# precision_score: 0.054786273329319686
# recall_score: 0.91
# f1_score: 0.10335036910846108

# %%
svc2 = SVC()

# %%
svc2.fit(x_train_res, y_train_res)
# Out:
# SVC()

# %%
svc2_pred = svc2.predict(x_test)

# %%
confusion_matrix(y_test, svc2_pred)
# Out:
# array([[55735,  1127],
#        [   13,    87]], dtype=int64)

# %%
print_results(y_test, svc2_pred)
# Out:
# accuracy_score: 0.9799866577718479
# precision_score: 0.07166392092257001
# recall_score: 0.87
# f1_score: 0.1324200913242009

# %%
rf2 = RandomForestClassifier(random_state=0)

# %%
rf2.fit(x_train_res, y_train_res)
# Out:
# RandomForestClassifier(random_state=0)

# %%
rf2_pred = rf2.predict(x_test)

# %%
confusion_matrix(y_test, rf2_pred)
# Out:
# array([[56851,    11],
#        [   15,    85]], dtype=int64)

# %%
print_results(y_test, rf2_pred)
# Out:
# accuracy_score: 0.9995435553526912
# precision_score: 0.8854166666666666
# recall_score: 0.85
# f1_score: 0.8673469387755102

# %%
plot_precision_recall_curve(rf2, x_test, y_test)

# %%
gbc2 = GradientBoostingClassifier(random_state=0)

# %%
gbc2.fit(x_train_res, y_train_res)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
gbc2_pred = gbc2.predict(x_test)

# %%
confusion_matrix(y_test, gbc2_pred)
# Out:
# array([[56172,   690],
#        [   10,    90]], dtype=int64)

# %%
print_results(y_test, gbc2_pred)
# Out:
# accuracy_score: 0.9877111056493802
# precision_score: 0.11538461538461539
# recall_score: 0.9
# f1_score: 0.20454545454545456

# %% [raw]
# My Conclusion----
# # 1.Good prediction results can be achieved with imbalanced datasets(better precision) as well as with balanced ones(better       recall)
# # 2.Random Forest and SVC gave us the best results being able to detect more than 85% fraud transactions and at the same time     not classifying a lot of non-fraud transactions as fraud
# # 3.There is no perfect model and there will always be a trade-off between precision and recall. It is up to the company and its   objectives to decide which approach is the best in each particular situation
